# %% [markdown]
# # Exploratory Data Analysis - Terrorism
# Dataset: https://bit.ly/2TK5Xn5

# %%
# Import all the essential libraries for our task
import pandas as pd
import numpy as np
import seaborn as sea
import matplotlib.pyplot as plt

# %%
#Loading the DataSet
df=pd.read_csv(R"C:\Users\bhoop\OneDrive\Documents\Desktop\globalterrorismdb_0718dist.csv",encoding=('ISO-8859-1'))
df
# Out:
# C:\Users\bhoop\AppData\Local\Temp\ipykernel_24700\3977782558.py:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(R"C:\Users\bhoop\OneDrive\Documents\Desktop\globalterrorismdb_0718dist.csv",encoding=('ISO-8859-1'))
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# ...

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# Observation
# The data consists of terrorist activities ranging from the year: 1970 to 2017
# Maximum number of people killed in an event were: 1570
# Maximum number of people wounded in an event were: 8191
# Maximum number of total casualties in an event were: 9574

# %%
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
df.shape
# Out:
# (181691, 135)

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in df.columns:
 print(i,end=" ,")
# Out:
# eventid ,iyear ,imonth ,iday ,approxdate ,extended ,resolution ,country ,country_txt ,region ,region_txt ,provstate ,city ,latitude ,longitude ,specificity ,vicinity ,location ,summary ,crit1 ,crit2 ,crit3 ,doubtterr ,alternative ,alternative_txt ,multiple ,success ,suicide ,attacktype1 ,attacktype1_txt ,attacktype2 ,attacktype2_txt ,attacktype3 ,attacktype3_txt ,targtype1 ,targtype1_txt ,targsubtype1 ,targsubtype1_txt ,corp1 ,target1 ,natlty1 ,natlty1_txt ,targtype2 ,targtype2_txt ,targsubtype2 ,targsubtype2_txt ,corp2 ,target2 ,natlty2 ,natlty2_txt ,targtype3 ,targtype3_txt ,targsubtype3 ,targsubtype3_txt ,corp3 ,target3 ,natlty3 ,natlty3_txt ,gname ,gsubname ,gname2 ,gsubname2 ,gname3 ,gsubname3 ,motive ,guncertain1 ,guncertain2 ,guncertain3 ,individual ,nperps ,nperpcap ,claimed ,claimmode ,claimmode_txt ,claim2 ,claimmode2 ,claimmode2_txt ,claim3 ,claimmode3 ,claimmode3_txt ,compclaim ,weaptype1 ,weaptype1_txt ,weapsubtype1 ,weapsubtype1_txt ,weaptype2 ,weaptype2_txt ,weapsubtyp
# ...

# %% [markdown]
# # Cleaning the data

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Obtaining Important columns of data
df=df[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]

# %%
df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
#Renaming the names of columns

# %%
df.rename(columns={"iyear":"Year","imonth":"Month","iday":"dy","country_txt":"Country","region_txt":"Region","provstate":"Province/State","city":"City","latitude":"Latitude","longitude":"Longitude","location":"Location","summary":"Summary","targtypel_txt":"Target Type","gname":"Group Name","motive":"Motive","weaptypel_txt":"Weapon Type","nkill":"Killed","nwound":"Wounded","addnotes":"Add Notes"},inplace=True)

# %%
df.head()
# Out:
#    Year  Month  dy             Country                       Region  \
# 0  1970      7   2  Dominican Republic  Central America & Caribbean
# 1  1970      0   0              Mexico                North America
# 2  1970      1   0         Philippines               Southeast Asia
# 3  1970      1   0              Greece               Western Europe
# 4  1970      1   0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
#To know the number of null values in data named df
df.isnull().sum()
# Out:
# Year                    0
# Month                   0
# dy                      0
# Country                 0
# Region                  0
# Province/State        421
# City                  434
# Latitude             4556
# Longitude            4557
# Location           126196
# Summary             66129
# attacktype1_txt         0
# targtype1_txt           0
# Group Name              0
# Motive             131130
# weaptype1_txt           0
# Killed              10313
# Wounded             16311
# Add Notes          153402
# dtype: int64

# %%
# Replacing null values with 0
df.fillna(0)
# Out:
#         Year  Month  dy             Country                       Region  \
# 0       1970      7   2  Dominican Republic  Central America & Caribbean
# 1       1970      0   0              Mexico                North America
# 2       1970      1   0         Philippines               Southeast Asia
# 3       1970      1   0              Greece               Western Europe
# 4       1970      1   0               Japan                    East Asia
# ...      ...    ...  ..                 ...                          ...
# 181686  2017     12  31             Somalia           Sub-Saharan Africa
# 181687  2017     12  31               Syria   Middle East & North Africa
# 181688  2017     12  31         Philippines               Southeast Asia
# 181689  2017     12  31               India                   South Asia
# 181690  2017     12  31         Philippines               Southeast Asia
#
#          Province/State           City   Latitude   Longitude  \
# ...

# %% [markdown]
# Visualizing the data
# 1. Year wise Attacks
# Number of Attacks in each Year

# %%
k=pd.DataFrame(df["Year"].value_counts().sort_index().reset_index())
k
# Out:
#     index   Year
# 0    1970    651
# 1    1971    471
# 2    1972    568
# 3    1973    473
# 4    1974    581
# 5    1975    740
# 6    1976    923
# 7    1977   1319
# 8    1978   1526
# 9    1979   2662
# 10   1980   2662
# 11   1981   2586
# 12   1982   2544
# 13   1983   2870
# 14   1984   3495
# 15   1985   2915
# 16   1986   2860
# 17   1987   3183
# 18   1988   3721
# 19   1989   4324
# 20   1990   3887
# 21   1991   4683
# 22   1992   5071
# 23   1994   3456
# 24   1995   3081
# 25   1996   3058
# 26   1997   3197
# 27   1998    934
# 28   1999   1395
# 29   2000   1814
# 30   2001   1906
# 31   2002   1333
# 32   2003   1278
# 33   2004   1166
# 34   2005   2017
# 35   2006   2758
# 36   2007   3242
# 37   2008   4805
# 38   2009   4721
# 39   2010   4826
# 40   2011   5076
# 41   2012   8522
# 42   2013  12036
# 43   2014  16903
# 44   2015  14965
# 45   2016  13587
# 46   2017  10900

# %%
attacks=k.rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")

# %%
attacks
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900

# %%
attacks.plot(kind="bar",color="red",figsize=(15,6),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# Casualities

# %%
df["Casuality"]=df["Killed"]+df["Wounded"]

# %%
cs=pd.DataFrame(df[["Year","Casuality"]]).set_index("Year").fillna(0).astype(int).groupby("Year").sum()
cs
# Out:
#       Casuality
# Year
# 1970        367
# 1971        119
# 1972        602
# 1973        621
# 1974       1122
# 1975        781
# 1976       1158
# 1977        874
# 1978       2664
# 1979       4378
# 1980       7532
# 1981       8106
# 1982       7512
# 1983      11271
# 1984      15462
# 1985      12004
# 1986      10524
# 1987      12141
# 1988      14014
# 1989      13617
# 1990      13261
# 1991      15961
# 1992      19610
# 1994      14663
# 1995      20233
# 1996      17383
# 1997      19468
# 1998      10754
# 1999       7819
# 2000       8890
# 2001      29662
# 2002      10356
# 2003      10126
# 2004      16911
# 2005      18258
# 2006      23740
# 2007      33728
# 2008      27594
# 2009      27210
# 2010      23651
# 2011      22566
# 2012      39380
# 2013      57679
# 2014      68853
# 2015      72833
# 2016      69225
# 2017      48208

# %%
cs.plot(kind="bar",color="green",figsize=(15,6),fontsize=13)
plt.title("Year wise Casualties",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Casualties",fontsize=15)
plt.show()

# %% [markdown]
# Number of PeopleKilled and Wounded in each Year

# %%
ki=pd.DataFrame(df[["Year","Killed"]]).fillna(0).astype(int).set_index("Year").groupby("Year").sum()
ki
ki.plot(kind="bar",color="blue",figsize=(15,6),fontsize=13)
plt.title("Year wise Killed",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Killed",fontsize=15)
plt.show()

# %%
wo=pd.DataFrame(df[["Year","Wounded"]]).fillna(0).astype(int).set_index("Year").groupby("Year").sum()
wo
wo.plot(kind="bar",color="blue",figsize=(15,6),fontsize=13)
plt.title("Year wise Wounded Persons",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Wounded Persons",fontsize=15)
plt.show()

# %% [markdown]
# 2. Region wise Attacks
# Distribution of Terrorist Attacks over Regions from 1970-2017

# %%
reg=pd.crosstab(df.Year,df.Region)
reg
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
# 1975                        0                            9             0
# 1976                        0                           45             0
# 1977                        0                           24             0
# 1978                        2                          199             0
# 1979                        2                          609             0
# 1980                        7                         1070             0
# 1981                        3                         1148             0
# ...

# %%
reg.plot(kind="area",figsize=(15,6),fontsize=13)
plt.title("Region Wise Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# Total Terrorist Attacks in each Region from 1970-2017

# %%
regn=(reg.sum(axis=0)).sort_values(ascending=False)
regn
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# dtype: int64

# %%
regn.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("Region Wise Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# Total Casualties (Killed + Wounded) in each Region

# %%
kil=pd.DataFrame(df[["Region","Casuality"]]).fillna(0).groupby("Region").sum().sort_values(by="Casuality",ascending=False)

kil
# Out:
#                              Casuality
# Region
# Middle East & North Africa    329807.0
# South Asia                    234366.0
# Sub-Saharan Africa            108990.0
# South America                  43562.0
# Southeast Asia                 40841.0
# Central America & Caribbean    34530.0
# North America                  26398.0
# Western Europe                 22778.0
# Eastern Europe                 18239.0
# East Asia                      10003.0
# Central Asia                    2969.0
# Australasia & Oceania            409.0

# %%
kil.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("Region Wise Casaulities",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Casaulities",fontsize=15)
plt.show()

# %% [markdown]
# 3. Country wise Attacks - Top 10
# Number of Attacks in each Country

# %%
coun=df["Country"].value_counts().head(15)
coun
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Somalia            4142
# Nigeria            3907
# Thailand           3849
# Yemen              3347
# Spain              3249
# Name: Country, dtype: int64

# %%
coun.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("Country Wise Casaulities",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Casaulities",fontsize=15)
plt.show()

# %%
# Country wise casualities
sdf=df[["Country","Casuality"]].fillna(0).groupby("Country").sum().sort_values(by="Casuality",ascending=False)
sdf1=sdf.head(10)

# %%
sdf1.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("Region Wise Casaulities",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Casaulities",fontsize=15)
plt.show()

# %% [markdown]
# 4. City wise Attacks - Top 10
# Number of Attacks in each city

# %%
city1=df["City"].value_counts().head(15)
city1
# Out:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Bogota           984
# Kirkuk           925
# Beirut           918
# Medellin         848
# Name: City, dtype: int64

# %%
city1.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("City wise Casaulities",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Casaulities",fontsize=15)
plt.show()

# %%
city2=df[["City","Casuality"]].fillna(0).groupby("City").sum().sort_values(by="Casuality",ascending=False).head(10)
city2
# Out:
#                Casuality
# City
# Baghdad          76897.0
# Unknown          31357.0
# New York City    19618.0
# Mosul            12360.0
# Karachi           9201.0
# Mogadishu         8603.0
# Kabul             8406.0
# Beirut            7210.0
# Kirkuk            6499.0
# Colombo           5852.0

# %%
city2.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("Region Wise Casaulities",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Casaulities",fontsize=15)
plt.show()

# %% [markdown]
# 5. Terrorist Group wise Attacks - Top 10
# Number of Attacks by each Group

# %%
grp=df["Group Name"].value_counts().head(15)
grp
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Communist Party of India - Maoist (CPI-Maoist)       1878
# Maoists                                              1630
# Liberation Tigers of Tamil Eelam (LTTE)              1606
# Name: Group Name, dtype: int64

# %%
grp.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("Group wise Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %%
grp2=df[["Group Name","Casuality"]].fillna(0).groupby("Group Name").sum().sort_values(by="Casuality",ascending=False)
mm=grp2.head(10)

# %%
mm.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("Casualties by each Group",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Casualties",fontsize=15)
plt.show()

# %% [markdown]
# 6. Attack Type wise Attacks
# Number of Attacks by each Attack Type

# %%
att=df["attacktype1_txt"].value_counts().head(15)
att
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'dy', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'attacktype1_txt',
#        'targtype1_txt', 'Group Name', 'Motive', 'weaptype1_txt', 'Killed',
#        'Wounded', 'Add Notes', 'Casuality'],
#       dtype='object')

# %%
att.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("Types of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %%
grp2=df[['attacktype1_txt',"Casuality"]].fillna(0).groupby('attacktype1_txt').sum()
grp2
# Out:
#                                      Casuality
# attacktype1_txt
# Armed Assault                         212386.0
# Assassination                          37209.0
# Bombing/Explosion                     514233.0
# Facility/Infrastructure Attack          6293.0
# Hijacking                              20642.0
# Hostage Taking (Barricade Incident)     7465.0
# Hostage Taking (Kidnapping)            20267.0
# Unarmed Assault                        14791.0
# Unknown                                39606.0

# %%
grp2.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("Casualties in each Attack",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Casaulities",fontsize=15)
plt.show()

# %% [markdown]
# 7. Target Type wise Attacks
# Number of Attacks over each Target Type

# %%
ta=df["targtype1_txt"].value_counts()
ta
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: targtype1_txt, dtype: int64

# %%
ta.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Types of Targets",fontsize=13)
plt.xlabel("Target Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %%
tc=df[["targtype1_txt","Casuality"]].fillna(0).groupby("targtype1_txt").sum().sort_values(by="Casuality",ascending=False)
tc
# Out:
#                                 Casuality
# targtype1_txt
# Private Citizens & Property      295314.0
# Military                         155194.0
# Police                           113272.0
# Business                          75477.0
# Government (General)              64957.0
# Transportation                    53791.0
# Religious Figures/Institutions    36031.0
# Terrorists/Non-State Militia      15617.0
# Educational Institution           13574.0
# Government (Diplomatic)           13121.0
# Violent Political Party            8646.0
# Unknown                            7673.0
# Airports & Aircraft                6795.0
# Journalists & Media                3093.0
# Utilities                          2746.0
# Tourists                           1993.0
# Maritime                           1965.0
# NGO                                1795.0
# Telecommunication                   676.0
# Other                               606.0
# Food or Water Supply                501.0
# ...

# %%
tc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Casualties in each Target Attack",fontsize=13)
plt.xlabel("Target Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# People Effected

# %%
casuality=df.loc[:,"Casuality"].sum()
casuality
# Out:
# 872892.0

# %%
casuality=df.loc[:,"Killed"].sum()
casuality
# Out:
# 411868.0

# %%
casuality=df.loc[:,"Wounded"].sum()
casuality
# Out:
# 523869.0

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'dy', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'attacktype1_txt',
#        'targtype1_txt', 'Group Name', 'Motive', 'weaptype1_txt', 'Killed',
#        'Wounded', 'Add Notes', 'Casuality'],
#       dtype='object')

# %% [markdown]
# Attacks per year:
# (i) Attacks (a) In 2014, there were 16903 attacks. (b) Fewest number of attacks: 471 in 1971
# (ii) Casualties (a) Most casualties: 85618 in 2014 (b) Fewest casualties: 255 in 1971
# (iii) Killed (a) The highest number of persons killed: 44490 in 2014 (b) The lowest number of people killed: 173 in 1971 (iv) Wounded (a) Most number of persons injured: 44043 in 2015 (b) Fewest number of people injured: 82 in 1971

# %% [markdown]
# Region-based attacks: (i) Attacks (a) The "Middle East & North Africa" had the most attacks: 50474. (b) Fewest attacks: 282 in "Australasia & Oceania" (ii) Casualties (a) Most casualties: 351950 in "Middle East & North Africa" (b) Fewest casualties: 410 in "Australasia & Oceania"

# %% [markdown]
# Attacks by Country :
#   (i) Assaults (a) The most attacks: 24636 in "Iraq" (b) The smallest number of attacks: 4292 in "Turkey"
#   (ii) Casualties (a) The most casualties: 213279 in "Iraq" (b) The fewest casualties: 22926 in "Philippines"

# %% [markdown]
# Attacks by City : (i) Attacks (a) The most attacks: 7589 in "Baghdad" (b) Fewest number of assaults: 1019 in "Athens"
#   (ii) Casualties (a) The most casualties: 77876 in "Baghdad" (b) Fewest casualties: 5748 in "Aleppo"

# %% [markdown]
# Terrorist Attacks by Terrorist Group:
#   (i) Assaults (a) The "Taliban" has carried out the most attacks: 7478. (b) "Boko Haram" has carried out the fewest attacks: 2418.
#   (ii) Casualties (a) The "Islamic State of Iraq and the Levant (ISIL)" has the highest number of casualties: 69595. (b) The "Farabundo Marti National Liberation Front (FMLN)" suffered the fewest casualties: 12130.

# %% [markdown]
# Terrorist Attacks on Humanity (Worldwide) from 1970 to 2017:
#   (i) Total number of casualties from terrorist attacks worldwide from 1970 to 2017: 935737
#   (ii) From 1970 to 2017, the total number of individuals murdered in terrorist attacks worldwide was 411868.
#
#   (iii) From 1970 to 2017, the total number of individuals killed in terrorist attacks worldwide was 523869.
